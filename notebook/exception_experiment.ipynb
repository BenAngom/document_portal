# %%
from logger.custom_logger import CustomLogger

# %%
logger=CustomLogger().get_logger("exception_experiment")

# %%
import sys
import traceback

class DocumentPortalException(Exception):
    """Custom exception for document portal"""
    def __init__(self, error_message:str, error_details:sys):
        _,_,exc_tb=error_details.exc_info()
        self.file_name = exc_tb.tb_frame.f_code.co_filename
        self.line_number = exc_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info())) 
    def __str__(self):
        return f"""
        Error occurred in file: {self.file_name} at line: {self.line_number}
        Error Message: {self.error_message}
        Traceback Details: {self.traceback_str}"""
    
if __name__ == "__main__":
    try:
        # simulate an error
        a = 1 / 0
        print(a)
    except Exception as e:
        app_exp = DocumentPortalException(e,sys)
        logger.error(app_exp)
        raise app_exp
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 21
#      19 try:
#      20     # simulate an error
# ---> 21     a = 1 / 0
#      22     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[4], line 26
#      24 app_exp = DocumentPortalException(e,sys)
#      25 logger.error(app_exp)
# ---> 26 raise app_exp
#
# DocumentPortalException:
#         Error occurred in file: /var/folders/6h/t71075kj4rz9vysz5fsdfz0h0000gn/T/ipykernel_95789/1194066645.py at line: 21
#         Error Message: division by zero
#         Traceback Details: Traceback (most recent call last):
#   File "/var/folders/6h/t71075kj4rz9vysz5fsdfz0h0000gn/T/ipykernel_95789/1194066645.py", line 21, in <module>
#     a = 1 / 0
# ZeroDivisionError: division by zero
