# %%
print("all good")
# Out:
# all good

# %%
import logging
import os
from datetime import datetime

# %%
logs_dir=os.path.join(os.getcwd(),"logs")

# %%
logs_dir
# Out:
# '/Users/benudhorangom/Documents/document_portal/notebook/logs'

# %%
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}.log"

# %%
LOG_FILE
# Out:
# '2026-01-26_18-44-55.log'

# %% [markdown]
# name of the log file

# %%
LOG_FILE_PATH=os.path.join(logs_dir, LOG_FILE)

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[%(asctime)s: %(levelname)s: %(module)s]: %(message)s", 
    level=logging.INFO,
)

# %%
logger = logging.getLogger("DocumentPortal")

# %%
logger.info("This is a info log message")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The following code is for using structs log

# %%
import structlog

# %%
logger = structlog.get_logger()

# %%
logger.info("This is a structlog info message" , user_id=-123 , filename="report.pdf")
# Out:
# 2026-01-26 18:44:55 [info     ] This is a structlog info message filename=report.pdf user_id=-123
